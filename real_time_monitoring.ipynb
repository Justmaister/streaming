# %%
import pandas as pd
import geopandas as gpd
import plotly_express as px
from datetime import datetime
import time
import os

current_dir = os.getcwd()

df = pd.read_csv(os.path.join(current_dir, 'LeesburgToIndy.csv'), sep=';', skiprows=1)

df = df[['LOCATION Latitude : ','LOCATION Longitude : ', 'LOCATION Altitude ( m)', 'LOCATION Altitude-google ( m)',
    'LOCATION Speed ( Kmh)', 'TEMPERATURE (F)', 'ATMOSPHERIC PRESSURE (hPa)', 'RELATIVE HUMIDITY (%)', 'SOUND LEVEL (dB)','YYYY-MO-DD HH-MI-SS_SSS']]
df.columns = ['Latitude', 'Longitude', 'Altitude', 'Altitude-google', 'Speed (Kmh)',
              'Temperature (F)', 'Atmospheric Pressure (hPa)', 'Relative Humidity (%)',
              'Sound Level (dB)', 'DateTime']
gdf = gpd.GeoDataFrame( df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude))
rgdf = gdf.iloc[50:251]
gdf.head(1)
# Out:
#     Latitude  Longitude  Altitude  Altitude-google  Speed (Kmh)  \
# 0  39.081585 -77.497055     212.9       313.746711          0.0
#
#    Temperature (F)  Atmospheric Pressure (hPa)  Relative Humidity (%)  \
# 0             60.2                     1016.65                   45.1
#
#    Sound Level (dB)                 DateTime                    geometry
# 0            53.361  2017-01-15 11:44:50:738  POINT (-77.49706 39.08158)

# %%
px.scatter_map(df, lat="Latitude", lon="Longitude" ,size_max=6, zoom=8, width=1000, height=500)
